# %%
import numpy as np
import pandas as pd
import lime
import lime.lime_tabular

import sklearn
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Fetching data and visualizing data

# %% [markdown]
# This data is availabe at: https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

# %%
cancer_data = pd.read_csv('../datasets/breast_cancer.csv')

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer_data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
list(cancer_data)
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %% [markdown]
# ### Create 3 dataframes for each type of feature: mean, se and worst

# %%
cancer_data.mean = cancer_data.filter(regex='_mean$')
cancer_data.se = cancer_data.filter(regex='_se$')
cancer_data.worst = cancer_data.filter(regex='_worst$')

# %% [markdown]
# ### Model training

# %% [markdown]
# The first mode will be trained with the mean dataset using all variables.

# %%
random_seed = 13

y = cancer_data['diagnosis'].values

X_train, X_test, y_train, y_test = train_test_split(cancer_data.mean, y, test_size=0.25, random_state=random_seed)

# %%
rf = RandomForestClassifier(n_estimators=20, random_state=random_seed)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=13, verbose=0, warm_start=False)

# %%
metrics.accuracy_score(y_test, rf.predict(X_test))
# Out:
# 0.9300699300699301

# %% [markdown]
# ### Create the explainer

# %% [markdown]
# For tabular data, LIME needs the dataset used for the training step.

# %%
explainer = lime.lime_tabular.LimeTabularExplainer(X_train.values, list(X_train), class_names = ['M','B'], discretize_continuous=True)
explainer

# %% [markdown]
# ### Explaining an instance

# %%
idx = 13
exp = explainer.explain_instance(X_test.values[idx], rf.predict_proba, num_features=4)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /local/matheus/tools/anaconda3/envs/python3/lib/python3.6/site-packages/lime/lime_tabular.py in explain_instance(self, data_row, predict_fn, labels, top_labels, num_features, num_samples, distance_metric, model_regressor)
#     300             try:
# --> 301                 assert isinstance(yss, np.ndarray) and len(yss.shape) == 1
#     302             except AssertionError:
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-f3b71363b711> in <module>()
#       1 idx = 13
# ----> 2 exp = explainer.explain_instance(X_test.values[idx], rf.predict_proba, num_features=4)
#
# ...

# %%
X_test.values[10].shape
# Out:
# (10,)
